# %%
a = 2 % 1
print(a)
# Out:
# 0

# %%
def cp(*args):
    total = 0
    for val in args :
        total += val
    return total
print(cp(1, 2, 3))
print(cp(10, 20))
# Out:
# 6
# 30

# %%
def mk(n):
    def add(x):
        return x + n
    return add

add3 = mk(3)
add7 = mk(7)
print(add3(10))
# Out:
# 13
