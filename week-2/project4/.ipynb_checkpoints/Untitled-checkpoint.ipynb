# %%
# Project IV: Izifin Technology ATR Calculator

# Requesting input from the user
experience = int(input("Enter years of work experience: "))
age = int(input("Enter age: "))

# Applying the selection logic
if experience > 25 and age >= 55:
    atr = 5600000
elif experience > 20 and age >= 45:
    atr = 4480000
elif experience > 10 and age >= 35:
    atr = 1500000
else:
    # Logic for staff < 10 years experience and < 35 years age
    atr = 550000

# Displaying the result
print(f"The Annual Tax Revenue (ATR) for the staff is: N{atr:,}")
# Out:
# Enter years of work experience:  69
# Enter age:  43
# The Annual Tax Revenue (ATR) for the staff is: N1,500,000
