# %%
pip install psycopg2-binary
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001D0272278C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/psycopg2-binary/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001D02732C190>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/psycopg2-binary/
# ...

# %%
pip install psycopg2-binary
# Out:
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.8 MB 1.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.6/2.8 MB 2.3 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.8 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.8 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.8 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.8 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.8 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.8 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.8 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.8 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.8 MB 1.6 MB/s eta 0:00:01
# ...

# %%
import psycopg2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 import psycopg2
# ----> 2 conn = psycopg2.connect(
#       3     host="localhost",
#       4     dbname="dbname",
#       5     port="port",
#       6     database="cos101_database",
#       7     user="postgres",
#       8     password="cos101"
#       9 )
#      11 cur = conn.cursor()
#
# File ~\Documents\New folder\Lib\site-packages\psycopg2\__init__.py:134, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     131 if 'async_' in kwargs:
#     132     kwasync['async_'] = kwargs.pop('async_')
# --> 134 dsn = _ext.make_dsn(dsn, **kwargs)
#     135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#
# File ~\Documents\New folder\Lib\site-packages\psycopg2\extensions.py:151, in make_dsn(dsn, **kwargs)
# ...
